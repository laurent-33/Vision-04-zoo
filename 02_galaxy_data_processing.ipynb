# %%
import pandas as pd
import numpy as np
import cv2
import matplotlib.pyplot as plt
from sklearn import metrics

# %%
img_path = '../../../images_training_rev1/100143.jpg'
img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img_grey = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

ret, thresh = cv2.threshold(img_grey, thresh=40, maxval=255, type=0)
contours, hierarchy = cv2.findContours(thresh, 1, 2)

max_numb = 0
for contour in contours:
    if len(contour) > max_numb:
        max_numb = len(contour)
        cnt = contour

# %%
rect = cv2.minAreaRect(cnt)
box = cv2.boxPoints(rect)
box = np.int0(box)
cv2.drawContours(img, [box], 0, (0, 0, 255), 2)

x,y,w,h = cv2.boundingRect(cnt)
cv2.rectangle(img, (x, y), (x+w, y+h), (255, 0, 0), 2)

plt.figure(figsize=(8,8))
plt.subplot(1, 2, 1)
plt.imshow(img)
plt.xticks([])
plt.yticks([])
plt.title(img.shape);

plt.subplot(1, 2, 2)
img = cv2.cvtColor(cv2.imread(img_path), cv2.COLOR_BGR2RGB)
img_crop = img[y:y+h, x:x+w]
plt.imshow(img_crop);
plt.xticks([])
plt.yticks([])
plt.title(img_crop.shape);

# %%
box
# Out:
# array([[228, 289],
#        [188, 287],
#        [193, 142],
#        [233, 144]])

# %%
contours
# Out:
# [array([[[288, 338]],
#
#         [[286, 340]],
#
#         [[286, 342]],
#
#         [[287, 343]],
#
#         [[290, 343]],
#
#         [[290, 339]],
#
#         [[289, 339]]], dtype=int32), array([[[115, 329]],
#
#         [[113, 331]],
#
#         [[112, 331]],
#
#         [[111, 332]],
#
#         [[110, 332]],
#
#         [[109, 333]],
#
#         [[109, 338]],
#
#         [[110, 339]],
#
#         [[111, 339]],
#
#         [[112, 340]],
#
#         [[120, 340]],
#
#         [[122, 338]],
#
#         [[123, 338]],
#
#         [[124, 337]],
#
#         [[124, 332]],
#
#         [[121, 329]]], dtype=int32), array([[[268, 298]],
#
#         [[267, 299]],
#
#         [[266, 299]],
#
#         [[266, 300]],
#
#         [[265, 301]],
#
#         [[266, 302]],
#
#         [[266, 303]],
#
#         [[267, 303]],
#
#         [[268, 304]],
#
#         [[271, 304]],
#
#         [[271, 298]]], dtype=int32), array([[[184, 248]],
#
# ...

# %%
i = 0
for contour in contours:
    print(i, cv2.pointPolygonTest(contour, (212, 212), False))
    i += 1
# Out:
# 0 -1.0
# 1 -1.0
# 2 -1.0
# 3 -1.0
# 4 -1.0
# 5 -1.0
# 6 -1.0
# 7 -1.0
# 8 -1.0
# 9 -1.0
# 10 1.0
# 11 -1.0
# 12 -1.0
# 13 -1.0
# 14 -1.0
# 15 -1.0
# 16 -1.0
# 17 -1.0
